# %% [markdown]
# ## 티스토리 블로그 자동 로그인 및 access token 발급 받기

# %%
import requests
import json
import re
import webbrowser
import pandas as pd

# App 아이디 설정-재발급-2020.11.26
client_id = 'a1f11d9eb54d53fcdb19da6026fa0fa7'
Secret_Key = 'a1f11d9eb54d53fcdb19da6026fa0fa7b31ac8af06b2bae7ed017161cb6332bb14bd06dc'

# tistory blog name: address id or full address
blog_name = "https://kkamagistory.tistory.com"

# Callback 설정
redirect_uri = 'https://kkamagistory.tistory.com'
#oauth_url = "https://www.tistory.com/oauth/authorize?client_id="+client_id+"&redirect_uri="+redirect_uri+"&response_type=token"
oauth_url = "https://www.tistory.com/oauth/authorize?client_id="+client_id+"&redirect_uri="+redirect_uri+"&response_type=code&state=someValue"
print(oauth_url)
output_type = "json"
requests_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36"
}

# tistory account 및 로그인 하기
#user_id = 'karas639@gmail.com'
user_id = 'karas639@kakao.com'
password = 'dwkimsec135@$^'

# http 요청 응답 체크
res = requests.get(oauth_url)
print(res.status_code)
#print(res.headers['Set-Cookie'])
#kakao_cookie = res.headers['Set-Cookie'].replace("; path=/",'')
#print(kakao_cookie)
print(res.url)

# header 및 login data 변수 정의
headers = {
    'Accept' : 'text/html, application/xhtml+xml, image/jxr, */*',
    'Accept-Encoding' : 'gzip, deflate',
    'Accept-Language' : 'ko, en-US; q=0.8, en; q=0.6, zh-Hans-CN; q=0.4, zh-Hans; q=0.2',
    'Cache-Control' : 'no-cache',
    'Connection' : 'Keep-Alive',
    'Content-Type' : 'application/x-www-form-urlencoded',
    #'Cookie' : kakao_cookie,
    'Host' : 'www.tistory.com',
    'Referer' : res.url,
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7.0; rv:11.0) like Gecko'
}
login_data = {
    'fp' : 'a1f11d9eb54d53fcdb19da6026fa0fa7',
    'keepLogin' : 'on',
    'loginId' : user_id,
    'password' : password,
    'redirectUrl' : res.url
}

code = '7282e014c869c2875a28f903de44a450b23a07a39c830d032def58378231ee77294604e7'
# access token 받아오기
req1 = "https://www.tistory.com/oauth/access_token?client_id="+client_id+"&client_secret="+Secret_Key+"&redirect_uri="+redirect_uri+"&code="+code+"&grant_type=authorization_code"
print(req1)
#res = requests.post(req1)
#res = requests.post('https://www.tistory.com/auth/login', headers=headers, data=login_data)
#print(res.url)
#match = re.match('(.*?)access_token=(?P<access_token>.*?)&state=', res.url)
#print(match)
#gd = match.groupdict()
#access_token = gd['access_token']
#print("access token : ", access_token)
# Out:
# https://www.tistory.com/oauth/authorize?client_id=a1f11d9eb54d53fcdb19da6026fa0fa7&redirect_uri=https://kkamagistory.tistory.com&response_type=code&state=someValue
# 200
# https://www.tistory.com/auth/login/?popup=1&redirectUrl=https%3A%2F%2Fwww.tistory.com%2Foauth%2Fauthorize%3Fclient_id%3Da1f11d9eb54d53fcdb19da6026fa0fa7%26redirect_uri%3Dhttps%3A%2F%2Fkkamagistory.tistory.com%26response_type%3Dcode%26state%3DsomeValue
# https://www.tistory.com/oauth/access_token?client_id=a1f11d9eb54d53fcdb19da6026fa0fa7&client_secret=a1f11d9eb54d53fcdb19da6026fa0fa7b31ac8af06b2bae7ed017161cb6332bb14bd06dc&redirect_uri=https://kkamagistory.tistory.com&code=7282e014c869c2875a28f903de44a450b23a07a39c830d032def58378231ee77294604e7&grant_type=authorization_code
# https://www.tistory.com/auth/login/?popup=1&redirectUrl=https%3A%2F%2Fwww.tistory.com%2Foauth%2Fauthorize%3Fclient_id%3Da1f11d9eb54d53fcdb19da6026fa0fa7%26redirect_uri%3Dhttps%3A%2F%2Fkkamagistory.tistory.com%26response_type%3Dcode%26state%3DsomeValue
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-e42f4e916671> in <module>
#      65 match = re.match('(.*?)access_token=(?P<access_token>.*?)&state=', res.url)
#      66 print(match)
# ---> 67 gd = match.groupdict()
#      68 access_token = gd['access_token']
#      69 print("access token : ", access_token)
#
# AttributeError: 'NoneType' object has no attribute 'groupdict'

# %% [markdown]
# ## 네이버 검색어 지정 및 기사(News) 크롤링

# %%
import os
import sys
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import requests
import requests as req
import webbrowser
import pandas as pd
import re
import string
import json

search = "국제반부패회의"
url = 'https://openapi.naver.com/v1/search/'+'news'+'?query='+search+'&display=4&start=1&sort=sim'
res = requests.get(urlparse(url).geturl(),
headers={'X-Naver-Client-Id': 'ys1o3hhvs_IL8YTasnby',
'X-Naver-Client-Secret': 'wYUFA7vyAs','User-Agent': 'Mozilla/5.0'})
#http 응답코드확인
#print(res.status_code)
#print(res.json())
json_data = res.json()
type(json_data)
#print(json_data['items'])
#print(json_data['title'])
x = json_data.values()
print(x['title'])



result = res.text
print(result + "\n" + "-"*70)
p = re.compile('^"title+', re.MULTILINE)

l = re.findall('[title":\s\[가-힣"]', result)
#x = re.compile('[title":\s\[가-힣"]').findall(result)
#x = re.compile('[ ㄱ-ㅣ가-힣]+').findall(result)
x = re.compile('[title": ㄱ-ㅣ가-힣]+').findall(result)
y = "".join(x)
print(y)
for title in re.findall("^title\s\:+", result):
    print(title)


#한글과 띄어쓰기 제외--> [^ ㄱ-ㅣ가-힣]+
#한글과 띄어쓰기만 --> [ ㄱ-ㅣ가-힣]+
# https://chulkang.tistory.com/32        
# http://blog.naver.com/okkam76/221320728630
# https://qkqhxla1.tistory.com/894
# https://wikidocs.net/80706
# https://medium.com/@dltkddud4403/python-%EC%A0%95%EA%B7%9C%ED%91%9C%ED%98%84%EC%8B%9D-ddbf0e58a20c
# https://developers.naver.com/docs/search/news/


#print(result.find('title'))
#title = naver_result[118:150]
#print(title)
#re.findall('title',data)
# Out:
# dict_values(['Wed, 02 Dec 2020 00:34:32 +0900', 7122, 1, 4, [{'title': "<b>국제반부패회의</b> 개막…전현희 권익위원장, '암행어사' 변신", 'originallink': 'http://yna.kr/AKR20201201136100001?did=1195m', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=001&aid=0012052312', 'description': '국민권익위원회와 국제반부패위원회(IACC), 국제투명성기구(TI)가 공동으로 주최하는 제19차 <b>국제반부패회의</b>가 1일부터 나흘간 온라인 화상회의 형태로 개최된다. 회의 기간에는 140여 개국 각료급 대표와 시민사회... ', 'pubDate': 'Tue, 01 Dec 2020 15:33:00 +0900'}, {'title': '[전문]文대통령, <b>국제반부패회의</b> 영상축사..“CPI 3년 연속 상승”', 'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04431286625994256', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004798455', 'description': '문 대통령은 이날 영상회의로 개최된 제19차 <b>국제반부패회의</b>에서 영상축사를 통해 “순위로도 2018년에 이어 2019년에도 여섯 계단씩 상승해, 역대 최고점수로 세계 30위권에 진입했다”라며 “한국의 목표는 2022년까지... ', 'pubDate': 'Tue, 01 Dec 2020 20:50:00 +0900'}, {'title': '[전문]문재인 대통령의 제19차 <b>국제반부패회의</b> 영상축사', 'originallink': 'http://www.newsis.com/view/?id=NISX20201201_0001254546&cID=10301&pID=10300', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=003&aid=0010217786', 'description': '/정리김태규 기자 = &lt;문재인 대통령의 제19차 <b>국제반부패회의</b> 영상축사 전문&gt; 존경하는 위겟 라벨르 <b>국제반부패회의</b> 의장님, 델리아 페레이라 루비오 국제투명성기구 회장님, 세계 반부패 분야 지도자와 전문가 여러분... ', 'pubDate': 'Tue, 01 Dec 2020 21:13:00 +0900'}, {'title': "<b>국제반부패회의</b> 개막…전현희 권익위원장, '암행어사' 변신", 'originallink': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1006100946&plink=ORI&cooper=NAVER', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=055&aid=0000858261', 'description': '국민권익위원회와 국제반부패위원회(IACC), 국제투명성기구(TI)가 공동으로 주최하는 제19차 <b>국제반부패회의</b>가 오늘(1일)부터 나흘간 온라인 화상회의 형태로 개최됩니다. 회의 기간에는 140여 개국 각료급 대표와... ', 'pubDate': 'Tue, 01 Dec 2020 16:41:00 +0900'}]])
# {
# "lastBuildDate": "Wed, 02 Dec 2020 00:34:32 +0900",
# "total": 7122,
# "start": 1,
# "display": 4,
# "items": [
# {
# "title": "<b>국제반부패회의</b> 개막…전현희 권익위원장, '암행어사' 변신",
# "originallink": "http://yna.kr/AKR20201201136100001?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=001&aid=0012052312",
# "description": "국민권익위원회와 국제반부패위원회(IACC), 국제투명성기구(TI)가 공동으로 주최하는 제19차 <b>국제반부패회의</b>가 1일부터 나흘간 온라인 화상회의 형태로 개최된다. 회의 기간에는 140여 개국 각료급 대표와 시민사회... ",
# "pubDate": "Tue, 01 Dec 2020 15:33:00 +0900"
#
# },
# {
# "title": "[전문]文대통령, <b>국제반부패회의</b> 영상축사..“CPI 3년 연속 상승”",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=04431286625994256",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004798455",
# "description": "문 대통령은 이날 영상회의로 개최된 제19차 <b>국제반부패회의</b>에서 영상축사를 통해 “순위로도 2018년에 이어 2019년에도 여섯 계단씩 상승해, 역대 최고점수로 세계 30위권에 진입했다”라며 “한국의 목표는 2022년까지... ",
# "pubDate": "Tue, 01 Dec 2020 20:50:00 +0900"
#
# },
# {
# "title": "[전문]문재인 대통령의 제19차 <b>국제반부패회의</b> 영상축사",
# "originallink": "http://www.newsis.com/view/?id=NISX20201201_0001254546&cID=10301&pID=10300",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=003&aid=0010217786",
# "description": "/정리김태규 기자 = &lt;문재인 대통령의 제19차 <b>국제반부패회의</b> 영상축사 전문&gt; 존경하는 위겟 라벨르 <b>국제반부패회의</b> 의장님, 델리아 페레이라 루비오 국제투명성기구 회장님, 세계 반부패 분야 지도자와 전문가 여러분... ",
# "pubDate": "Tue, 01 Dec 2020 21:13:00 +0900"
#
# },
# {
# "title": "<b>국제반부패회의</b> 개막…전현희 권익위원장, '암행어사' 변신",
# "originallink": "https://news.sbs.co.kr/news/endPage.do?news_id=N1006100946&plink=ORI&cooper=NAVER",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=055&aid=0000858261",
# "description": "국민권익위원회와 국제반부패위원회(IACC), 국제투명성기구(TI)가 공동으로 주최하는 제19차 <b>국제반부패회의</b>가 오늘(1일)부터 나흘간 온라인 화상회의 형태로 개최됩니다. 회의 기간에는 140여 개국 각료급 대표와... ",
# "pubDate": "Tue, 01 Dec 2020 16:41:00 +0900"
#
# }
# ]
# }
#
# ----------------------------------------------------------------------
# "ltilte": "e  e  :: ""ttl": "tt": "il": "ite": "title": "국제반부패회의 개막전현희 권익위원장 암행어사 변신""iilli": "tt:i""li": "tt:eeieeieiii""eiti": "국민권익위원회와 국제반부패위원회 국제투명성기구가 공동으로 주최하는 제차 국제반부패회의가 일부터 나흘간 온라인 화상회의 형태로 개최된다 회의 기간에는 여 개국 각료급 대표와 시민사회 ""te": "e  e  :: ""title": "전문대통령 국제반부패회의 영상축사 년 연속 상승""iilli": "tt:eileetei""li": "tt:eeieeieiii""eiti": "문 대통령은 이날 영상회의로 개최된 제차 국제반부패회의에서 영상축사를 통해 순위로도 년에 이어 년에도 여섯 계단씩 상승해 역대 최고점수로 세계 위권에 진입했다라며 한국의 목표는 년까지 ""te": "e  e  :: ""title": "전문문재인 대통령의 제차 국제반부패회의 영상축사""iilli": "tt:eiiei""li": "tt:eeieeieiii""eiti": "정리김태규 기자  lt문재인 대통령의 제차 국제반부패회의 영상축사 전문t 존경하는 위겟 라벨르 국제반부패회의 의장님 델리아 페레이라 루비오 국제투명성기구 회장님 세계 반부패 분야 지도자와 전문가 여러분 ""te": "e  e  :: ""title": "국제반부패회의 개막전현희 권익위원장 암행어사 변신""iilli": "tt:eeeeeilie""li": "tt:eeieeieiii""eiti": "국민권익위원회와 국제반부패위원회 국제투명성기구가 공동으로 주최하는 제차 국제반부패회의가 오늘일부터 나흘간 온라인 화상회의 형태로 개최됩니다 회의 기간에는 여 개국 각료급 대표와 ""te": "e  e  :: "

# %%
access_token = '70567d7295df82e5aa4837bff1751a99_833d675491192312ff1d06118acea24a'
def get_info():
    info_url = f'https://www.tistory.com/apis/blog/info?access_token={access_token}&output={output_type}'
    r =requests.get(info_url, headers=requests_headers)
    return r.text

def get_list(page_number):
    url = f'https://www.tistory.com/apis/post/list?access_token={access_token}&output={output_type}&blogName={blog_name}&page={page_number}'
    r = requests.get(url, headers = requests_headers)
    return r.text

def get_category():
    url = f'https://www.tistory.com/apis/category/list?access_token={access_token}&output={output_type}&blogName={blog_name}'
    r = requests.get(url, headers=requests_headers)
    r = r.json()['tistory']['item']['categories']
    for i in r:
        print(f'{i["name"]} ({i["id"]})')
    return r

def get_write():
    title = title1 #제목 (필수)
    content = naver_result #글내용(필수)
    visibility = "3" #발행상태 0비공개-기본, 1보고,3발행
    category_id = "889078" #카테고리 아이디 기본값 0
    published ="" #기본값 : 현재시간
    slogan = "" #문자주소
    tag = "코로나, 코로나19, 실시간 뉴스" #태그 ,로 구분
    acceptComment = "1" #댓글 허용 (0, 1 - 기본값)
    password = "" #보호글 비밀번호
    url = f'https://www.tistory.com/apis/post/write?access_token={access_token}&output={output_type}&blogName={blog_name}&title={title}&content={content}&visibility={visibility}&category={category_id}&slogan={slogan}&tag={tag}&acceptComment={acceptComment}&password={password}'
    r = requests.post(url)
    print(r, r.text)
    
def file_upload():
    files = {'uploadedfile': open(filepath, 'rb')}
    params = {'access_token': access_token, 'blogName': kkamagistory, 'targetUrl': blogName, 'output': 'json'}
    rd = requests.post('https://www.tistory.com/apis/post/attach', params=params, files=files)
 
    try:
        item = json.loads(rd.text)
        print(json.dumps(item, indent=4))
        print("----------------------------------------------")
        print(item["tistory"]["replacer"])
        print(item["tistory"]["url"])
        print(item["tistory"]["status"])
    except:
        print("Failed")
 
 
get_category()
get_write()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3692cad232b8> in <module>
#      48
#      49
# ---> 50 get_category()
#      51 get_write()
#
# <ipython-input-7-3692cad232b8> in get_category()
#      11
#      12 def get_category():
# ---> 13     url = f'https://www.tistory.com/apis/category/list?access_token={access_token}&output={output_type}&blogName={blog_name}'
#      14     r = requests.get(url, headers=requests_headers)
#      15     r = r.json()['tistory']['item']['categories']
#
# NameError: name 'output_type' is not defined

# %%
from selenium import webdriver

# webdriver 안에 있는 여러 클래스 중 크롬클래스를 사용해서 크롬을 띄우며, 크롬드라이버 위치를 지정한다
driver = webdriver.Chrome('./chromedriver')

try:
    driver.get('https://news.naver.com')
    
    elem = driver.find_element_by_id('_rankingList0')
    #print(elem.text)
    
    lis = elem.find_element_by_tag_name('li')
    print(lis.text)
    
        
    input()
except Exception as e:
    print(e)
finally:
    driver.quit()
# Out:
# Message: no such element: Unable to locate element: {"method":"id","selector":"right.ranking_contents"}
#   (Session info: chrome=87.0.4280.88)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 10.0.19042 x86_64)

# %% [markdown]
# # 2020.6.15일 변경사항
#
# ### 참고 : https://godpeople.or.kr/board/4927670
# -400에러가 발생하면서 "access_token 이 유효하지 않습니다."라는 에러가 발생하는 경우에 대한 패치
# -원인, request로 처리하는 과정에서 해더 정보를 새롭게 체크하는 것 같습니다.
# -해당 해더 정보를 추가하면 됩니다.
# - 아래 참고
#
# requests_headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36"
# }
#
# requests.get(url, headers=requests_headers)

# %% [markdown]
# # 2020.11.26
# ## tistory api 동작 방식 변경 - implicit X -> authorization으로.
# - https://tistory.github.io/document-tistory-apis/auth/authorization_code.html
# - https://m.blog.naver.com/chandong83/221958663807
# - https://limsee.com/325
# - https://nemowork.com/entry/%ED%8B%B0%EC%8A%A4%ED%86%A0%EB%A6%AC-API%EA%B0%80-%EC%9E%AC%EB%8C%80%EB%A1%9C-%EB%8F%99%EC%9E%91%ED%95%98%EC%A7%80-%EC%95%8A%EC%95%98%EB%8D%98-%EC%9D%B4%EC%9C%A0%EB%A5%BC-%EC%95%8C%EC%95%84%EB%82%B4%EB%8B%A4
# - https://tariat.tistory.com/128
# - 파이썬 티스토리 API 예제 (https://m.blog.naver.com/chandong83/221958663807)
# - 파이썬 티스토리 API 이용 (https://yoyoii.tistory.com/352)
# - 파이썬 티스토리 API access token 확인하기 (https://tariat.tistory.com/128)
# - 파이썬을 이용한 티스토리 제목 및 카테고리 크롤링 (https://smorning.tistory.com/266)
# - 파이썬으로 크롬 개발자도구 네트워크 탭 크롤링 하기
